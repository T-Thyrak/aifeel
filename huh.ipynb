# %%
# %load_ext autoreload
# %autoreload 2

# %%
from aifeel.model.nn import NNClassifier
from sklearn.utils.estimator_checks import check_estimator
# Out:
# WARNING:tensorflow:From d:\projects\aifeel\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
base_feature_count = 5

# %%
model = NNClassifier(epochs=10, batch_size=32, lr=0.0001)

# %%
gen = check_estimator(model, generate_only=True)

# %%
for estim, check in gen:
    try:
        # print(estim, check)
        check(estim)
    except Exception as e:
        print(e)
# Out:
# WARNING:tensorflow:From d:\projects\aifeel\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/10
# WARNING:tensorflow:From d:\projects\aifeel\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\projects\aifeel\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1/1 [==============================] - 3s 3s/step - loss: 0.7816 - accuracy: 0.3889 - val_loss: 0.6211 - val_accuracy: 1.0000
# Epoch 2/10
# 1/1 [==============================] - 0s 96ms/step - loss: 0.7161 - accuracy: 0.5000 - val_loss: 0.6328 - val_accuracy: 1.0000
# Epoch 3/10
# ...
